# %%
#Importing libraries and loading the dataset into python
import os
import pandas as pd
print("Current working directory:", os.getcwd())
df = pd.read_csv("../data/Healthcare.csv")
df.head()
# Out:
# Current working directory: C:\Users\rahom\healthcare-symptom-classification\Notebooks
#    Patient_ID  Age  Gender                                           Symptoms  \
# 0           1   29    Male              fever, back pain, shortness of breath
# 1           2   76  Female                   insomnia, back pain, weight loss
# 2           3   78    Male                    sore throat, vomiting, diarrhea
# 3           4   58   Other  blurred vision, depression, weight loss, muscl...
# 4           5   55  Female                    swelling, appetite loss, nausea
#
#    Symptom_Count           Disease
# 0              3           Allergy
# 1              3  Thyroid Disorder
# 2              3         Influenza
# 3              4            Stroke
# 4              3     Heart Disease

# %%
#Viewing the first 20 rows to ensure the data structure is correct
df = pd.read_csv("../data/Healthcare.csv") 

print("FIRST 30 ROWS:")
print(df.head(30))

print("\nCOLUMN NAMES:")
print(df.columns)

print("\nTOP 30 DISEASE COUNTS:")
print(df["Disease"].value_counts().head(30))
# Out:
# FIRST 30 ROWS:
#     Patient_ID  Age  Gender  \
# 0            1   29    Male
# 1            2   76  Female
# 2            3   78    Male
# 3            4   58   Other
# 4            5   55  Female
# 5            6   49    Male
# 6            7   69    Male
# 7            8   25   Other
# 8            9   11    Male
# 9           10   47    Male
# 10          11   78   Other
# 11          12   72    Male
# 12          13   52  Female
# 13          14   64  Female
# 14          15   34   Other
# 15          16   12    Male
# 16          17   88  Female
# 17          18   33   Other
# 18          19   69  Female
# 19          20   34   Other
# 20          21   82   Other
# 21          22   68    Male
# 22          23   40    Male
# 23          24    9   Other
# 24          25   34   Other
# 25          26   40  Female
# 26          27    3   Other
# 27          28   81    Male
# 28          29   66    Male
# 29          30   32  Female
#
# ...
